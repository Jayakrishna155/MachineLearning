# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayakrishna155/MachineLearning/blob/main/NaiveBayesTitanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Datasets/titanic.csv")
data.head()
# Out:
#    PassengerId                                               Name  Pclass  ... Cabin  Embarked  Survived
# 0            1                            Braund, Mr. Owen Harris       3  ...   NaN         S         0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  ...   C85         C         1
# 2            3                             Heikkinen, Miss. Laina       3  ...   NaN         S         1
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  ...  C123         S         1
# 4            5                           Allen, Mr. William Henry       3  ...   NaN         S         0
#
# [5 rows x 12 columns]

# %%
x = data[['Pclass','Sex','Age','Fare']]
y = data['Survived']
print(x[:5])
print(y[:5])
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
dummies = pd.get_dummies(x.Sex)
dummies.head()
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False
# 3    True  False
# 4   False   True

# %%
x = pd.concat([x,dummies],axis = 1)
x.drop('Sex',axis=1,inplace=True)
x.head()
# Out:
#    Pclass   Age     Fare  female   male  female   male
# 0       3  22.0   7.2500   False   True   False   True
# 1       1  38.0  71.2833    True  False    True  False
# 2       3  26.0   7.9250    True  False    True  False
# 3       1  35.0  53.1000    True  False    True  False
# 4       3  35.0   8.0500   False   True   False   True

# %%
x.columns[x.isna().any()]
# Out:
# Index([], dtype='object')

# %%
x.fillna(x.Age.mean(),inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.8044692737430168

# %%
model.predict_proba(x_test[:10])
# Out:
# array([[9.90850849e-01, 9.14915093e-03],
#        [1.25593740e-04, 9.99874406e-01],
#        [1.98844886e-04, 9.99801155e-01],
#        [9.98737848e-01, 1.26215164e-03],
#        [1.80736272e-04, 9.99819264e-01],
#        [1.99759776e-04, 9.99800240e-01],
#        [9.93755367e-01, 6.24463329e-03],
#        [1.86659746e-06, 9.99998133e-01],
#        [9.97380078e-01, 2.61992233e-03],
#        [9.97867225e-01, 2.13277529e-03]])
